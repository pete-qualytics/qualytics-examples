# %%
import snowflake.connector
import os
from dotenv import find_dotenv, load_dotenv
import pandas as pd
import seaborn as sns
#import numpy as np
#from scipy import stats
#from datetime import datetime
#from sklearn import preprocessing
#from sklearn.model_selection import KFold
#from sklearn.linear_model import LinearRegression


load_dotenv(find_dotenv())


conn = snowflake.connector.connect(
        user = os.getenv('SNOWFLAKE_USER'),
        password = os.getenv('SNOWFLAKE_PASSWORD'),
        account = os.getenv('SNOWFLAKE_ACCOUNT'),
        warehouse = 'QUALYTICS_WH',
        database = 'MEDALLION_ARCHITECTURE_DEMO',
        schema = 'DEMO',
        autocommit = True)


cursor = conn.cursor()
query=(f"""select S.ISSUE_YEAR YEAR,
                    max(L.POPULATION) POPULATION,
                    count(distinct S.id) LOAN_COUNT
                from DEMO.SILVER_LC_LOANS S
                join demo.lookups_lc_state_population L on (S.ADDR_STATE = L.STATE and S.ISSUE_YEAR = L.YEAR)
            group by S.ADDR_STATE, S.ISSUE_YEAR;""")
print(query)
output = cursor.execute(query)

df = cursor.fetch_pandas_all()

cursor.close()
del cursor 
conn.close()

#print(df.to_markdown()) 
sns.lmplot(x='POPULATION', y='LOAN_COUNT', data=df, hue='YEAR')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Untitled-1.ipynb Cell 1' in <cell line: 17>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=5'>6</a> #import numpy as np
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=6'>7</a> #from scipy import stats
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=7'>8</a> #from datetime import datetime
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=8'>9</a> #from sklearn import preprocessing
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=9'>10</a> #from sklearn.model_selection import KFold
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=10'>11</a> #from sklearn.linear_model import LinearRegression
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=13'>14</a> load_dotenv(find_dotenv())
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=16'>17</a> conn = snowflake.connector.connect(
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=17'>18</a>         user = os.getenv('SNOWFLAKE_USER'),
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=18'>19</a>         password = os.getenv('SNOWFLAKE_PASSWORD'),
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=19'>20</a>         account = os.getenv('SNOWFLAKE_ACCOUNT'),
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=20'>21</a>         warehouse = 'QUALYTICS_WH',
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=21'>22</a>         database = 'MEDALLION_ARCHITECTURE_DEMO',
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=22'>23</a>         schema = 'DEMO',
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=23'>24</a>         autocommit = True)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=26'>27</a> cursor = conn.cursor()
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=27'>28</a> query=(f"""select S.ISSUE_YEAR YEAR,
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=28'>29</a>                     max(L.POPULATION) POPULATION,
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=29'>30</a>                     count(distinct S.id) LOAN_COUNT
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=30'>31</a>                 from DEMO.SILVER_LC_LOANS S
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=31'>32</a>                 join demo.lookups_lc_state_population L on (S.ADDR_STATE = L.STATE and S.ISSUE_YEAR = L.YEAR)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=32'>33</a>             group by S.ADDR_STATE, S.ISSUE_YEAR;""")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\snowflake\connector\__init__.py:51, in Connect(**kwargs)
#      <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/__init__.py?line=49'>50</a> def Connect(**kwargs) -> SnowflakeConnection:
# ---> <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/__init__.py?line=50'>51</a>     return SnowflakeConnection(**kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\snowflake\connector\connection.py:276, in SnowflakeConnection.__init__(self, **kwargs)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=273'>274</a> self.converter = None
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=274'>275</a> self.__set_error_attributes()
# --> <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=275'>276</a> self.connect(**kwargs)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=276'>277</a> self._telemetry = TelemetryClient(self._rest)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\snowflake\connector\connection.py:486, in SnowflakeConnection.connect(self, **kwargs)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=483'>484</a> logger.debug("connect")
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=484'>485</a> if len(kwargs) > 0:
# --> <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=485'>486</a>     self.__config(**kwargs)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=486'>487</a>     TelemetryService.get_instance().update_context(kwargs)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=488'>489</a> self.__open_connection()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\snowflake\connector\connection.py:836, in SnowflakeConnection.__config(self, **kwargs)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=831'>832</a>         self._authenticator = auth_tmp
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=833'>834</a> if not self.user and self._authenticator != OAUTH_AUTHENTICATOR:
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=834'>835</a>     # OAuth Authentication does not require a username
# --> <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=835'>836</a>     Error.errorhandler_wrapper(
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=836'>837</a>         self,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=837'>838</a>         None,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=838'>839</a>         ProgrammingError,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=839'>840</a>         {"msg": "User is empty", "errno": ER_NO_USER},
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=840'>841</a>     )
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=842'>843</a> if self._private_key:
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/connection.py?line=843'>844</a>     self._authenticator = KEY_PAIR_AUTHENTICATOR
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\snowflake\connector\errors.py:273, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=249'>250</a> @staticmethod
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=250'>251</a> def errorhandler_wrapper(
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=251'>252</a>     connection: SnowflakeConnection | None,
#    (...)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=254'>255</a>     error_value: dict[str, str | bool | int],
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=255'>256</a> ) -> None:
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=256'>257</a>     """Error handler wrapper that calls the errorhandler method.
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=257'>258</a>
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=258'>259</a>     Args:
#    (...)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=269'>270</a>         exception to the first handler in that order.
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=270'>271</a>     """
# --> <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=272'>273</a>     handed_over = Error.hand_to_other_handler(
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=273'>274</a>         connection,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=274'>275</a>         cursor,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=275'>276</a>         error_class,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=276'>277</a>         error_value,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=277'>278</a>     )
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=278'>279</a>     if not handed_over:
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=279'>280</a>         raise Error.errorhandler_make_exception(
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=280'>281</a>             error_class,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=281'>282</a>             error_value,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=282'>283</a>         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\snowflake\connector\errors.py:331, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=328'>329</a>     return True
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=329'>330</a> elif connection is not None:
# --> <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=330'>331</a>     connection.errorhandler(connection, cursor, error_class, error_value)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=331'>332</a>     return True
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=332'>333</a> return False
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\snowflake\connector\errors.py:207, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=188'>189</a> @staticmethod
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=189'>190</a> def default_errorhandler(
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=190'>191</a>     connection: SnowflakeConnection,
#    (...)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=193'>194</a>     error_value: dict[str, str],
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=194'>195</a> ) -> None:
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=195'>196</a>     """Default error handler that raises an error.
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=196'>197</a>
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=197'>198</a>     Args:
#    (...)
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=204'>205</a>         A Snowflake error.
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=205'>206</a>     """
# --> <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=206'>207</a>     raise error_class(
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=207'>208</a>         msg=error_value.get("msg"),
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=208'>209</a>         errno=error_value.get("errno"),
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=209'>210</a>         sqlstate=error_value.get("sqlstate"),
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=210'>211</a>         sfqid=error_value.get("sfqid"),
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=211'>212</a>         done_format_msg=error_value.get("done_format_msg"),
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=212'>213</a>         connection=connection,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=213'>214</a>         cursor=cursor,
#     <a href='file:///c%3A/Users/pete/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/snowflake/connector/errors.py?line=214'>215</a>     )
#
# ProgrammingError: 251005: User is empty
